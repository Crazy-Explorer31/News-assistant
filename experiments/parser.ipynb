# %% [markdown]
# <a href="https://colab.research.google.com/github/Crazy-Explorer31/News-assistant/blob/main/parser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Классификация новостных данных. Парсер

# %%
# Установка библиотек
# !pip install bs4
# !pip install openpyxl
# Out:
# Requirement already satisfied: bs4 in /usr/local/lib/python3.11/dist-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from bs4) (4.13.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->bs4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->bs4) (4.12.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl) (2.0.0)

# %%
import requests as rq
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %%
def get_url(param_dict: dict) -> str:
    """
    Возвращает URL для запроса json таблицы со статьями

    url = 'https://lenta.ru/search/v2/process?'\
    + 'from=0&'\                       # Смещение
    + 'size=1000&'\                    # Кол-во статей
    + 'sort=2&'\                       # Сортировка по дате (2), по релевантности (1)
    + 'title_only=0&'\                 # Точная фраза в заголовке
    + 'modified%2Cformat=yyyy-MM-dd&'\ # Формат даты
    + 'type=1&'\                       # Материалы. Все материалы (0). Новость (1)
    + 'bloc=4&'\                       # Рубрика. Экономика (4). Все рубрики (0)
    + 'modified%2Cfrom=2020-01-01&'\
    + 'modified%2Cto=2020-11-01&'\
    + 'query='                         # Поисковой запрос
    """
    hasType = int(param_dict['type']) != 0
    hasBloc = int(param_dict['bloc']) != 0

    url = 'https://lenta.ru/search/v2/process?'\
    + 'from={}&'.format(param_dict['from'])\
    + 'size={}&'.format(param_dict['size'])\
    + 'sort={}&'.format(param_dict['sort'])\
    + 'title_only={}&'.format(param_dict['title_only'])\
    + 'modified%2Cformat=yyyy-MM-dd&'\
    + 'type={}&'.format(param_dict['type']) * hasType\
    + 'bloc={}&'.format(param_dict['bloc']) * hasBloc\
    + 'modified%2Cfrom={}&'.format(param_dict['dateFrom'])\
    + 'modified%2Cto={}&'.format(param_dict['dateTo'])\
    + 'query={}'.format(param_dict['query'])

    return url

def get_search_table(param_dict: dict) -> pd.DataFrame:
    """
    Возвращает pd.DataFrame со списком статей
    """
    url = get_url(param_dict)
    r = rq.get(url)
    search_table = pd.DataFrame(r.json()['matches'])
    return search_table


def get_articles(param_dict,
                  time_step = 37,
                  save_every = 5,
                  save_excel = True) -> pd.DataFrame:
    """
    Функция для скачивания статей интервалами через каждые time_step дней
    Делает сохранение таблицы через каждые save_every * time_step дней

    param_dict: dict
    ### Параметры запроса
    ###### project - раздел поиска, например, rbcnews
    ###### category - категория поиска, например, TopRbcRu_economics
    ###### dateFrom - с даты
    ###### dateTo - по дату
    ###### offset - смещение поисковой выдачи
    ###### limit - лимит статей, максимум 100
    ###### query - поисковой запрос (ключевое слово), например, РБК

    """
    param_copy = param_dict.copy()
    time_step = timedelta(days=time_step)
    dateFrom = datetime.strptime(param_copy['dateFrom'], '%Y-%m-%d')
    dateTo = datetime.strptime(param_copy['dateTo'], '%Y-%m-%d')

    out = pd.DataFrame()
    save_counter = 0

    while dateFrom <= dateTo:
      param_copy['dateTo'] = (dateFrom + time_step).strftime('%Y-%m-%d')
      if dateFrom + time_step > dateTo:
          param_copy['dateTo'] = dateTo.strftime('%Y-%m-%d')

      print('Parsing articles from '\
            + param_copy['dateFrom'] +  ' to ' + param_copy['dateTo'])
      out = pd.concat([out, get_search_table(param_copy)], ignore_index=True)
      dateFrom += time_step + timedelta(days=1)
      param_copy['dateFrom'] = dateFrom.strftime('%Y-%m-%d')
      save_counter += 1

    print('Finish')

    return out

# %%
# Задаем тут параметры
query = ''
offset = 0
size = 300
sort = "2"
title_only = ""
domain = ""
material = "0"
bloc = "1" # topic = тематика новости
dateFrom = '2023-01-01'
dateTo = "2025-03-20"
param_dict = {'query'     : query,
              'from'      : str(offset),
              'size'      : str(size),
              'dateFrom'  : dateFrom,
              'dateTo'    : dateTo,
              'sort'      : sort,
              'title_only': title_only,
              'type'      : material,
              'bloc'      : bloc,
              'domain'    : domain}

# %%
df = pd.DataFrame()
for bloc in range(9):
  param_dict["bloc"] = str(bloc)
  tbl = get_articles(param_dict=param_dict,
                          time_step = 5,
                          save_every = 10)
  print(len(tbl.index))
  print(tbl.shape)
  tbl.head(3)
  df = pd.concat([df, tbl])
# Out:
# Parsing articles from 2023-01-01 to 2023-01-06
# Parsing articles from 2023-01-07 to 2023-01-12
# Parsing articles from 2023-01-13 to 2023-01-18
# Parsing articles from 2023-01-19 to 2023-01-24
# Parsing articles from 2023-01-25 to 2023-01-30
# Parsing articles from 2023-01-31 to 2023-02-05
# Parsing articles from 2023-02-06 to 2023-02-11
# Parsing articles from 2023-02-12 to 2023-02-17
# Parsing articles from 2023-02-18 to 2023-02-23
# Parsing articles from 2023-02-24 to 2023-03-01
# Parsing articles from 2023-03-02 to 2023-03-07
# Parsing articles from 2023-03-08 to 2023-03-13
# Parsing articles from 2023-03-14 to 2023-03-19
# Parsing articles from 2023-03-20 to 2023-03-25
# Parsing articles from 2023-03-26 to 2023-03-31
# Parsing articles from 2023-04-01 to 2023-04-06
# Parsing articles from 2023-04-07 to 2023-04-12
# Parsing articles from 2023-04-13 to 2023-04-18
# Parsing articles from 2023-04-19 to 2023-04-24
# Parsing articles from 2023-04-25 to 2023-04-30
# Parsing articles from 2023-05-01 to 2023-05-06
# Parsing articles from 2023-05-07 to 2023-05-12
# Parsing articles from 2023-05-13 to 2023-05-18
# Parsing articles from 2023-05-19 to 2023-05-24
# Parsing articles from 2023-05-25 to 2023-05-30
# Parsing articles from 2023-05-31 to 2023-06-05
# Parsing articles from 2023-06-06 to 2023-06-11
# Parsing articles from 2023-06-12 to 2023-06-17
# Parsing articles from 2023-06-18 to 2023-06-23
# Parsing articles from 2023-06-24 to 2023-06-29
# Parsing articles from 2023-06-30 to 2023-07-05
# Parsing articles from 2023-07-06 to 2023-07-11
# Parsing articles from 2023-07-12 to 2023-07-17
# Parsing articles from 2023-07-18 to 2023-07-23
# Parsing articles from 2023-07-24 to 2023-07-29
# Parsing articles from 2023-07-30 to 2023-08-04
# Parsing articles from 2023-08-05 to 2023-08-10
# Parsing articles from 2023-08-11 to 2023-08-16
# Parsing articles from 2023-08-17 to 2023-08-22
# Parsing articles from 2023-08-23 to 2023-08-28
# Parsing articles from 2023-08-29 to 2023-09-03
# Parsing articles from 2023-09-04 to 2023-09-09
# Parsing articles from 2023-09-10 to 2023-09-15
# Parsing articles from 2023-09-16 to 2023-09-21
# Parsing articles from 2023-09-22 to 2023-09-27
# Parsing articles from 2023-09-28 to 2023-10-03
# Parsing articles from 2023-10-04 to 2023-10-09
# Parsing articles from 2023-10-10 to 2023-10-15
# Parsing articles from 2023-10-16 to 2023-10-21
# Parsing articles from 2023-10-22 to 2023-10-27
# Parsing articles from 2023-10-28 to 2023-11-02
# Parsing articles from 2023-11-03 to 2023-11-08
# Parsing articles from 2023-11-09 to 2023-11-14
# Parsing articles from 2023-11-15 to 2023-11-20
# Parsing articles from 2023-11-21 to 2023-11-26
# Parsing articles from 2023-11-27 to 2023-12-02
# Parsing articles from 2023-12-03 to 2023-12-08
# Parsing articles from 2023-12-09 to 2023-12-14
# Parsing articles from 2023-12-15 to 2023-12-20
# Parsing articles from 2023-12-21 to 2023-12-26
# Parsing articles from 2023-12-27 to 2024-01-01
# Parsing articles from 2024-01-02 to 2024-01-07
# Parsing articles from 2024-01-08 to 2024-01-13
# Parsing articles from 2024-01-14 to 2024-01-19
# Parsing articles from 2024-01-20 to 2024-01-25
# Parsing articles from 2024-01-26 to 2024-01-31
# Parsing articles from 2024-02-01 to 2024-02-06
# Parsing articles from 2024-02-07 to 2024-02-12
# Parsing articles from 2024-02-13 to 2024-02-18
# Parsing articles from 2024-02-19 to 2024-02-24
# Parsing articles from 2024-02-25 to 2024-03-01
# Parsing articles from 2024-03-02 to 2024-03-07
# Parsing articles from 2024-03-08 to 2024-03-13
# Parsing articles from 2024-03-14 to 2024-03-19
# Parsing articles from 2024-03-20 to 2024-03-25
# Parsing articles from 2024-03-26 to 2024-03-31
# Parsing articles from 2024-04-01 to 2024-04-06
# Parsing articles from 2024-04-07 to 2024-04-12
# Parsing articles from 2024-04-13 to 2024-04-18
# Parsing articles from 2024-04-19 to 2024-04-24
# Parsing articles from 2024-04-25 to 2024-04-30
# Parsing articles from 2024-05-01 to 2024-05-06
# Parsing articles from 2024-05-07 to 2024-05-12
# Parsing articles from 2024-05-13 to 2024-05-18
# Parsing articles from 2024-05-19 to 2024-05-24
# Parsing articles from 2024-05-25 to 2024-05-30
# Parsing articles from 2024-05-31 to 2024-06-05
# Parsing articles from 2024-06-06 to 2024-06-11
# Parsing articles from 2024-06-12 to 2024-06-17
# Parsing articles from 2024-06-18 to 2024-06-23
# Parsing articles from 2024-06-24 to 2024-06-29
# Parsing articles from 2024-06-30 to 2024-07-05
# Parsing articles from 2024-07-06 to 2024-07-11
# Parsing articles from 2024-07-12 to 2024-07-17
# Parsing articles from 2024-07-18 to 2024-07-23
# Parsing articles from 2024-07-24 to 2024-07-29
# Parsing articles from 2024-07-30 to 2024-08-04
# Parsing articles from 2024-08-05 to 2024-08-10
# Parsing articles from 2024-08-11 to 2024-08-16
# Parsing articles from 2024-08-17 to 2024-08-22
# Parsing articles from 2024-08-23 to 2024-08-28
# Parsing articles from 2024-08-29 to 2024-09-03
# Parsing articles from 2024-09-04 to 2024-09-09
# Parsing articles from 2024-09-10 to 2024-09-15
# Parsing articles from 2024-09-16 to 2024-09-21
# Parsing articles from 2024-09-22 to 2024-09-27
# Parsing articles from 2024-09-28 to 2024-10-03
# Parsing articles from 2024-10-04 to 2024-10-09
# Parsing articles from 2024-10-10 to 2024-10-15
# Parsing articles from 2024-10-16 to 2024-10-21
# Parsing articles from 2024-10-22 to 2024-10-27
# Parsing articles from 2024-10-28 to 2024-11-02
# Parsing articles from 2024-11-03 to 2024-11-08
# Parsing articles from 2024-11-09 to 2024-11-14
# Parsing articles from 2024-11-15 to 2024-11-20
# Parsing articles from 2024-11-21 to 2024-11-26
# Parsing articles from 2024-11-27 to 2024-12-02
# Parsing articles from 2024-12-03 to 2024-12-08
# Parsing articles from 2024-12-09 to 2024-12-14
# Parsing articles from 2024-12-15 to 2024-12-20
# Parsing articles from 2024-12-21 to 2024-12-26
# Parsing articles from 2024-12-27 to 2025-01-01
# Parsing articles from 2025-01-02 to 2025-01-07
# Parsing articles from 2025-01-08 to 2025-01-13
# Parsing articles from 2025-01-14 to 2025-01-19
# Parsing articles from 2025-01-20 to 2025-01-25
# Parsing articles from 2025-01-26 to 2025-01-31
# Parsing articles from 2025-02-01 to 2025-02-06
# Parsing articles from 2025-02-07 to 2025-02-12
# Parsing articles from 2025-02-13 to 2025-02-18
# Parsing articles from 2025-02-19 to 2025-02-24
# Parsing articles from 2025-02-25 to 2025-03-02
# Parsing articles from 2025-03-03 to 2025-03-08
# Parsing articles from 2025-03-09 to 2025-03-14
# Parsing articles from 2025-03-15 to 2025-03-20
# Finish
# 40500
# (40500, 16)
# Parsing articles from 2023-01-01 to 2023-01-06
# Parsing articles from 2023-01-07 to 2023-01-12
# Parsing articles from 2023-01-13 to 2023-01-18
# Parsing articles from 2023-01-19 to 2023-01-24
# Parsing articles from 2023-01-25 to 2023-01-30
# Parsing articles from 2023-01-31 to 2023-02-05
# Parsing articles from 2023-02-06 to 2023-02-11
# Parsing articles from 2023-02-12 to 2023-02-17
# Parsing articles from 2023-02-18 to 2023-02-23
# Parsing articles from 2023-02-24 to 2023-03-01
# Parsing articles from 2023-03-02 to 2023-03-07
# Parsing articles from 2023-03-08 to 2023-03-13
# Parsing articles from 2023-03-14 to 2023-03-19
# Parsing articles from 2023-03-20 to 2023-03-25
# Parsing articles from 2023-03-26 to 2023-03-31
# Parsing articles from 2023-04-01 to 2023-04-06
# Parsing articles from 2023-04-07 to 2023-04-12
# Parsing articles from 2023-04-13 to 2023-04-18
# Parsing articles from 2023-04-19 to 2023-04-24
# Parsing articles from 2023-04-25 to 2023-04-30
# Parsing articles from 2023-05-01 to 2023-05-06
# Parsing articles from 2023-05-07 to 2023-05-12
# Parsing articles from 2023-05-13 to 2023-05-18
# Parsing articles from 2023-05-19 to 2023-05-24
# Parsing articles from 2023-05-25 to 2023-05-30
# Parsing articles from 2023-05-31 to 2023-06-05
# Parsing articles from 2023-06-06 to 2023-06-11
# Parsing articles from 2023-06-12 to 2023-06-17
# Parsing articles from 2023-06-18 to 2023-06-23
# Parsing articles from 2023-06-24 to 2023-06-29
# Parsing articles from 2023-06-30 to 2023-07-05
# Parsing articles from 2023-07-06 to 2023-07-11
# Parsing articles from 2023-07-12 to 2023-07-17
# Parsing articles from 2023-07-18 to 2023-07-23
# Parsing articles from 2023-07-24 to 2023-07-29
# Parsing articles from 2023-07-30 to 2023-08-04
# Parsing articles from 2023-08-05 to 2023-08-10
# Parsing articles from 2023-08-11 to 2023-08-16
# Parsing articles from 2023-08-17 to 2023-08-22
# Parsing articles from 2023-08-23 to 2023-08-28
# Parsing articles from 2023-08-29 to 2023-09-03
# Parsing articles from 2023-09-04 to 2023-09-09
# Parsing articles from 2023-09-10 to 2023-09-15
# Parsing articles from 2023-09-16 to 2023-09-21
# Parsing articles from 2023-09-22 to 2023-09-27
# Parsing articles from 2023-09-28 to 2023-10-03
# Parsing articles from 2023-10-04 to 2023-10-09
# Parsing articles from 2023-10-10 to 2023-10-15
# Parsing articles from 2023-10-16 to 2023-10-21
# Parsing articles from 2023-10-22 to 2023-10-27
# Parsing articles from 2023-10-28 to 2023-11-02
# Parsing articles from 2023-11-03 to 2023-11-08
# Parsing articles from 2023-11-09 to 2023-11-14
# Parsing articles from 2023-11-15 to 2023-11-20
# Parsing articles from 2023-11-21 to 2023-11-26
# Parsing articles from 2023-11-27 to 2023-12-02
# Parsing articles from 2023-12-03 to 2023-12-08
# Parsing articles from 2023-12-09 to 2023-12-14
# Parsing articles from 2023-12-15 to 2023-12-20
# Parsing articles from 2023-12-21 to 2023-12-26
# Parsing articles from 2023-12-27 to 2024-01-01
# Parsing articles from 2024-01-02 to 2024-01-07
# Parsing articles from 2024-01-08 to 2024-01-13
# Parsing articles from 2024-01-14 to 2024-01-19
# Parsing articles from 2024-01-20 to 2024-01-25
# Parsing articles from 2024-01-26 to 2024-01-31
# Parsing articles from 2024-02-01 to 2024-02-06
# Parsing articles from 2024-02-07 to 2024-02-12
# Parsing articles from 2024-02-13 to 2024-02-18
# Parsing articles from 2024-02-19 to 2024-02-24
# Parsing articles from 2024-02-25 to 2024-03-01
# Parsing articles from 2024-03-02 to 2024-03-07
# Parsing articles from 2024-03-08 to 2024-03-13
# Parsing articles from 2024-03-14 to 2024-03-19
# Parsing articles from 2024-03-20 to 2024-03-25
# Parsing articles from 2024-03-26 to 2024-03-31
# Parsing articles from 2024-04-01 to 2024-04-06
# Parsing articles from 2024-04-07 to 2024-04-12
# Parsing articles from 2024-04-13 to 2024-04-18
# Parsing articles from 2024-04-19 to 2024-04-24
# Parsing articles from 2024-04-25 to 2024-04-30
# Parsing articles from 2024-05-01 to 2024-05-06
# Parsing articles from 2024-05-07 to 2024-05-12
# Parsing articles from 2024-05-13 to 2024-05-18
# Parsing articles from 2024-05-19 to 2024-05-24
# Parsing articles from 2024-05-25 to 2024-05-30
# Parsing articles from 2024-05-31 to 2024-06-05
# Parsing articles from 2024-06-06 to 2024-06-11
# Parsing articles from 2024-06-12 to 2024-06-17
# Parsing articles from 2024-06-18 to 2024-06-23
# Parsing articles from 2024-06-24 to 2024-06-29
# Parsing articles from 2024-06-30 to 2024-07-05
# Parsing articles from 2024-07-06 to 2024-07-11
# Parsing articles from 2024-07-12 to 2024-07-17
# Parsing articles from 2024-07-18 to 2024-07-23
# Parsing articles from 2024-07-24 to 2024-07-29
# Parsing articles from 2024-07-30 to 2024-08-04
# Parsing articles from 2024-08-05 to 2024-08-10
# Parsing articles from 2024-08-11 to 2024-08-16
# Parsing articles from 2024-08-17 to 2024-08-22
# Parsing articles from 2024-08-23 to 2024-08-28
# Parsing articles from 2024-08-29 to 2024-09-03
# Parsing articles from 2024-09-04 to 2024-09-09
# Parsing articles from 2024-09-10 to 2024-09-15
# Parsing articles from 2024-09-16 to 2024-09-21
# Parsing articles from 2024-09-22 to 2024-09-27
# Parsing articles from 2024-09-28 to 2024-10-03
# Parsing articles from 2024-10-04 to 2024-10-09
# Parsing articles from 2024-10-10 to 2024-10-15
# Parsing articles from 2024-10-16 to 2024-10-21
# Parsing articles from 2024-10-22 to 2024-10-27
# Parsing articles from 2024-10-28 to 2024-11-02
# Parsing articles from 2024-11-03 to 2024-11-08
# Parsing articles from 2024-11-09 to 2024-11-14
# Parsing articles from 2024-11-15 to 2024-11-20
# Parsing articles from 2024-11-21 to 2024-11-26
# Parsing articles from 2024-11-27 to 2024-12-02
# Parsing articles from 2024-12-03 to 2024-12-08
# Parsing articles from 2024-12-09 to 2024-12-14
# Parsing articles from 2024-12-15 to 2024-12-20
# Parsing articles from 2024-12-21 to 2024-12-26
# Parsing articles from 2024-12-27 to 2025-01-01
# Parsing articles from 2025-01-02 to 2025-01-07
# Parsing articles from 2025-01-08 to 2025-01-13
# Parsing articles from 2025-01-14 to 2025-01-19
# Parsing articles from 2025-01-20 to 2025-01-25
# Parsing articles from 2025-01-26 to 2025-01-31
# Parsing articles from 2025-02-01 to 2025-02-06
# Parsing articles from 2025-02-07 to 2025-02-12
# Parsing articles from 2025-02-13 to 2025-02-18
# Parsing articles from 2025-02-19 to 2025-02-24
# Parsing articles from 2025-02-25 to 2025-03-02
# Parsing articles from 2025-03-03 to 2025-03-08
# Parsing articles from 2025-03-09 to 2025-03-14
# Parsing articles from 2025-03-15 to 2025-03-20
# Finish
# 40463
# (40463, 16)
# Parsing articles from 2023-01-01 to 2023-01-06
# Parsing articles from 2023-01-07 to 2023-01-12
# Parsing articles from 2023-01-13 to 2023-01-18
# Parsing articles from 2023-01-19 to 2023-01-24
# Parsing articles from 2023-01-25 to 2023-01-30
# Parsing articles from 2023-01-31 to 2023-02-05
# Parsing articles from 2023-02-06 to 2023-02-11
# Parsing articles from 2023-02-12 to 2023-02-17
# Parsing articles from 2023-02-18 to 2023-02-23
# Parsing articles from 2023-02-24 to 2023-03-01
# Parsing articles from 2023-03-02 to 2023-03-07
# Parsing articles from 2023-03-08 to 2023-03-13
# Parsing articles from 2023-03-14 to 2023-03-19
# Parsing articles from 2023-03-20 to 2023-03-25
# Parsing articles from 2023-03-26 to 2023-03-31
# Parsing articles from 2023-04-01 to 2023-04-06
# Parsing articles from 2023-04-07 to 2023-04-12
# Parsing articles from 2023-04-13 to 2023-04-18
# Parsing articles from 2023-04-19 to 2023-04-24
# Parsing articles from 2023-04-25 to 2023-04-30
# Parsing articles from 2023-05-01 to 2023-05-06
# Parsing articles from 2023-05-07 to 2023-05-12
# Parsing articles from 2023-05-13 to 2023-05-18
# Parsing articles from 2023-05-19 to 2023-05-24
# Parsing articles from 2023-05-25 to 2023-05-30
# Parsing articles from 2023-05-31 to 2023-06-05
# Parsing articles from 2023-06-06 to 2023-06-11
# Parsing articles from 2023-06-12 to 2023-06-17
# Parsing articles from 2023-06-18 to 2023-06-23
# Parsing articles from 2023-06-24 to 2023-06-29
# Parsing articles from 2023-06-30 to 2023-07-05
# Parsing articles from 2023-07-06 to 2023-07-11
# Parsing articles from 2023-07-12 to 2023-07-17
# Parsing articles from 2023-07-18 to 2023-07-23
# Parsing articles from 2023-07-24 to 2023-07-29
# Parsing articles from 2023-07-30 to 2023-08-04
# Parsing articles from 2023-08-05 to 2023-08-10
# Parsing articles from 2023-08-11 to 2023-08-16
# Parsing articles from 2023-08-17 to 2023-08-22
# Parsing articles from 2023-08-23 to 2023-08-28
# Parsing articles from 2023-08-29 to 2023-09-03
# Parsing articles from 2023-09-04 to 2023-09-09
# Parsing articles from 2023-09-10 to 2023-09-15
# Parsing articles from 2023-09-16 to 2023-09-21
# Parsing articles from 2023-09-22 to 2023-09-27
# Parsing articles from 2023-09-28 to 2023-10-03
# Parsing articles from 2023-10-04 to 2023-10-09
# Parsing articles from 2023-10-10 to 2023-10-15
# Parsing articles from 2023-10-16 to 2023-10-21
# Parsing articles from 2023-10-22 to 2023-10-27
# Parsing articles from 2023-10-28 to 2023-11-02
# Parsing articles from 2023-11-03 to 2023-11-08
# Parsing articles from 2023-11-09 to 2023-11-14
# Parsing articles from 2023-11-15 to 2023-11-20
# Parsing articles from 2023-11-21 to 2023-11-26
# Parsing articles from 2023-11-27 to 2023-12-02
# Parsing articles from 2023-12-03 to 2023-12-08
# Parsing articles from 2023-12-09 to 2023-12-14
# Parsing articles from 2023-12-15 to 2023-12-20
# Parsing articles from 2023-12-21 to 2023-12-26
# Parsing articles from 2023-12-27 to 2024-01-01
# Parsing articles from 2024-01-02 to 2024-01-07
# Parsing articles from 2024-01-08 to 2024-01-13
# Parsing articles from 2024-01-14 to 2024-01-19
# Parsing articles from 2024-01-20 to 2024-01-25
# Parsing articles from 2024-01-26 to 2024-01-31
# Parsing articles from 2024-02-01 to 2024-02-06
# Parsing articles from 2024-02-07 to 2024-02-12
# Parsing articles from 2024-02-13 to 2024-02-18
# Parsing articles from 2024-02-19 to 2024-02-24
# Parsing articles from 2024-02-25 to 2024-03-01
# Parsing articles from 2024-03-02 to 2024-03-07
# Parsing articles from 2024-03-08 to 2024-03-13
# Parsing articles from 2024-03-14 to 2024-03-19
# Parsing articles from 2024-03-20 to 2024-03-25
# Parsing articles from 2024-03-26 to 2024-03-31
# Parsing articles from 2024-04-01 to 2024-04-06
# Parsing articles from 2024-04-07 to 2024-04-12
# Parsing articles from 2024-04-13 to 2024-04-18
# Parsing articles from 2024-04-19 to 2024-04-24
# Parsing articles from 2024-04-25 to 2024-04-30
# Parsing articles from 2024-05-01 to 2024-05-06
# Parsing articles from 2024-05-07 to 2024-05-12
# Parsing articles from 2024-05-13 to 2024-05-18
# Parsing articles from 2024-05-19 to 2024-05-24
# Parsing articles from 2024-05-25 to 2024-05-30
# Parsing articles from 2024-05-31 to 2024-06-05
# Parsing articles from 2024-06-06 to 2024-06-11
# Parsing articles from 2024-06-12 to 2024-06-17
# Parsing articles from 2024-06-18 to 2024-06-23
# Parsing articles from 2024-06-24 to 2024-06-29
# Parsing articles from 2024-06-30 to 2024-07-05
# Parsing articles from 2024-07-06 to 2024-07-11
# Parsing articles from 2024-07-12 to 2024-07-17
# Parsing articles from 2024-07-18 to 2024-07-23
# Parsing articles from 2024-07-24 to 2024-07-29
# Parsing articles from 2024-07-30 to 2024-08-04
# Parsing articles from 2024-08-05 to 2024-08-10
# Parsing articles from 2024-08-11 to 2024-08-16
# Parsing articles from 2024-08-17 to 2024-08-22
# Parsing articles from 2024-08-23 to 2024-08-28
# Parsing articles from 2024-08-29 to 2024-09-03
# Parsing articles from 2024-09-04 to 2024-09-09
# Parsing articles from 2024-09-10 to 2024-09-15
# Parsing articles from 2024-09-16 to 2024-09-21
# Parsing articles from 2024-09-22 to 2024-09-27
# Parsing articles from 2024-09-28 to 2024-10-03
# Parsing articles from 2024-10-04 to 2024-10-09
# Parsing articles from 2024-10-10 to 2024-10-15
# Parsing articles from 2024-10-16 to 2024-10-21
# Parsing articles from 2024-10-22 to 2024-10-27
# Parsing articles from 2024-10-28 to 2024-11-02
# Parsing articles from 2024-11-03 to 2024-11-08
# Parsing articles from 2024-11-09 to 2024-11-14
# Parsing articles from 2024-11-15 to 2024-11-20
# Parsing articles from 2024-11-21 to 2024-11-26
# Parsing articles from 2024-11-27 to 2024-12-02
# Parsing articles from 2024-12-03 to 2024-12-08
# Parsing articles from 2024-12-09 to 2024-12-14
# Parsing articles from 2024-12-15 to 2024-12-20
# Parsing articles from 2024-12-21 to 2024-12-26
# Parsing articles from 2024-12-27 to 2025-01-01
# Parsing articles from 2025-01-02 to 2025-01-07
# Parsing articles from 2025-01-08 to 2025-01-13
# Parsing articles from 2025-01-14 to 2025-01-19
# Parsing articles from 2025-01-20 to 2025-01-25
# Parsing articles from 2025-01-26 to 2025-01-31
# Parsing articles from 2025-02-01 to 2025-02-06
# Parsing articles from 2025-02-07 to 2025-02-12
# Parsing articles from 2025-02-13 to 2025-02-18
# Parsing articles from 2025-02-19 to 2025-02-24
# Parsing articles from 2025-02-25 to 2025-03-02
# Parsing articles from 2025-03-03 to 2025-03-08
# Parsing articles from 2025-03-09 to 2025-03-14
# Parsing articles from 2025-03-15 to 2025-03-20
# Finish
# 40500
# (40500, 16)
# Parsing articles from 2023-01-01 to 2023-01-06
# Parsing articles from 2023-01-07 to 2023-01-12
# Parsing articles from 2023-01-13 to 2023-01-18
# Parsing articles from 2023-01-19 to 2023-01-24
# Parsing articles from 2023-01-25 to 2023-01-30
# Parsing articles from 2023-01-31 to 2023-02-05
# Parsing articles from 2023-02-06 to 2023-02-11
# Parsing articles from 2023-02-12 to 2023-02-17
# Parsing articles from 2023-02-18 to 2023-02-23
# Parsing articles from 2023-02-24 to 2023-03-01
# Parsing articles from 2023-03-02 to 2023-03-07
# Parsing articles from 2023-03-08 to 2023-03-13
# Parsing articles from 2023-03-14 to 2023-03-19
# Parsing articles from 2023-03-20 to 2023-03-25
# Parsing articles from 2023-03-26 to 2023-03-31
# Parsing articles from 2023-04-01 to 2023-04-06
# Parsing articles from 2023-04-07 to 2023-04-12
# Parsing articles from 2023-04-13 to 2023-04-18
# Parsing articles from 2023-04-19 to 2023-04-24
# Parsing articles from 2023-04-25 to 2023-04-30
# Parsing articles from 2023-05-01 to 2023-05-06
# Parsing articles from 2023-05-07 to 2023-05-12
# Parsing articles from 2023-05-13 to 2023-05-18
# Parsing articles from 2023-05-19 to 2023-05-24
# Parsing articles from 2023-05-25 to 2023-05-30
# Parsing articles from 2023-05-31 to 2023-06-05
# Parsing articles from 2023-06-06 to 2023-06-11
# Parsing articles from 2023-06-12 to 2023-06-17
# Parsing articles from 2023-06-18 to 2023-06-23
# Parsing articles from 2023-06-24 to 2023-06-29
# Parsing articles from 2023-06-30 to 2023-07-05
# Parsing articles from 2023-07-06 to 2023-07-11
# Parsing articles from 2023-07-12 to 2023-07-17
# Parsing articles from 2023-07-18 to 2023-07-23
# Parsing articles from 2023-07-24 to 2023-07-29
# Parsing articles from 2023-07-30 to 2023-08-04
# Parsing articles from 2023-08-05 to 2023-08-10
# Parsing articles from 2023-08-11 to 2023-08-16
# Parsing articles from 2023-08-17 to 2023-08-22
# Parsing articles from 2023-08-23 to 2023-08-28
# Parsing articles from 2023-08-29 to 2023-09-03
# Parsing articles from 2023-09-04 to 2023-09-09
# Parsing articles from 2023-09-10 to 2023-09-15
# Parsing articles from 2023-09-16 to 2023-09-21
# Parsing articles from 2023-09-22 to 2023-09-27
# Parsing articles from 2023-09-28 to 2023-10-03
# Parsing articles from 2023-10-04 to 2023-10-09
# Parsing articles from 2023-10-10 to 2023-10-15
# Parsing articles from 2023-10-16 to 2023-10-21
# Parsing articles from 2023-10-22 to 2023-10-27
# Parsing articles from 2023-10-28 to 2023-11-02
# Parsing articles from 2023-11-03 to 2023-11-08
# Parsing articles from 2023-11-09 to 2023-11-14
# Parsing articles from 2023-11-15 to 2023-11-20
# Parsing articles from 2023-11-21 to 2023-11-26
# Parsing articles from 2023-11-27 to 2023-12-02
# Parsing articles from 2023-12-03 to 2023-12-08
# Parsing articles from 2023-12-09 to 2023-12-14
# Parsing articles from 2023-12-15 to 2023-12-20
# Parsing articles from 2023-12-21 to 2023-12-26
# Parsing articles from 2023-12-27 to 2024-01-01
# Parsing articles from 2024-01-02 to 2024-01-07
# Parsing articles from 2024-01-08 to 2024-01-13
# Parsing articles from 2024-01-14 to 2024-01-19
# Parsing articles from 2024-01-20 to 2024-01-25
# Parsing articles from 2024-01-26 to 2024-01-31
# Parsing articles from 2024-02-01 to 2024-02-06
# Parsing articles from 2024-02-07 to 2024-02-12
# Parsing articles from 2024-02-13 to 2024-02-18
# Parsing articles from 2024-02-19 to 2024-02-24
# Parsing articles from 2024-02-25 to 2024-03-01
# Parsing articles from 2024-03-02 to 2024-03-07
# Parsing articles from 2024-03-08 to 2024-03-13
# Parsing articles from 2024-03-14 to 2024-03-19
# Parsing articles from 2024-03-20 to 2024-03-25
# Parsing articles from 2024-03-26 to 2024-03-31
# Parsing articles from 2024-04-01 to 2024-04-06
# Parsing articles from 2024-04-07 to 2024-04-12
# Parsing articles from 2024-04-13 to 2024-04-18
# Parsing articles from 2024-04-19 to 2024-04-24
# Parsing articles from 2024-04-25 to 2024-04-30
# Parsing articles from 2024-05-01 to 2024-05-06
# Parsing articles from 2024-05-07 to 2024-05-12
# Parsing articles from 2024-05-13 to 2024-05-18
# Parsing articles from 2024-05-19 to 2024-05-24
# Parsing articles from 2024-05-25 to 2024-05-30
# Parsing articles from 2024-05-31 to 2024-06-05
# Parsing articles from 2024-06-06 to 2024-06-11
# Parsing articles from 2024-06-12 to 2024-06-17
# Parsing articles from 2024-06-18 to 2024-06-23
# Parsing articles from 2024-06-24 to 2024-06-29
# Parsing articles from 2024-06-30 to 2024-07-05
# Parsing articles from 2024-07-06 to 2024-07-11
# Parsing articles from 2024-07-12 to 2024-07-17
# Parsing articles from 2024-07-18 to 2024-07-23
# Parsing articles from 2024-07-24 to 2024-07-29
# Parsing articles from 2024-07-30 to 2024-08-04
# Parsing articles from 2024-08-05 to 2024-08-10
# Parsing articles from 2024-08-11 to 2024-08-16
# Parsing articles from 2024-08-17 to 2024-08-22
# Parsing articles from 2024-08-23 to 2024-08-28
# Parsing articles from 2024-08-29 to 2024-09-03
# Parsing articles from 2024-09-04 to 2024-09-09
# Parsing articles from 2024-09-10 to 2024-09-15
# Parsing articles from 2024-09-16 to 2024-09-21
# Parsing articles from 2024-09-22 to 2024-09-27
# Parsing articles from 2024-09-28 to 2024-10-03
# Parsing articles from 2024-10-04 to 2024-10-09
# Parsing articles from 2024-10-10 to 2024-10-15
# Parsing articles from 2024-10-16 to 2024-10-21
# Parsing articles from 2024-10-22 to 2024-10-27
# Parsing articles from 2024-10-28 to 2024-11-02
# Parsing articles from 2024-11-03 to 2024-11-08
# Parsing articles from 2024-11-09 to 2024-11-14
# Parsing articles from 2024-11-15 to 2024-11-20
# Parsing articles from 2024-11-21 to 2024-11-26
# Parsing articles from 2024-11-27 to 2024-12-02
# Parsing articles from 2024-12-03 to 2024-12-08
# Parsing articles from 2024-12-09 to 2024-12-14
# Parsing articles from 2024-12-15 to 2024-12-20
# Parsing articles from 2024-12-21 to 2024-12-26
# Parsing articles from 2024-12-27 to 2025-01-01
# Parsing articles from 2025-01-02 to 2025-01-07
# Parsing articles from 2025-01-08 to 2025-01-13
# Parsing articles from 2025-01-14 to 2025-01-19
# Parsing articles from 2025-01-20 to 2025-01-25
# Parsing articles from 2025-01-26 to 2025-01-31
# Parsing articles from 2025-02-01 to 2025-02-06
# Parsing articles from 2025-02-07 to 2025-02-12
# Parsing articles from 2025-02-13 to 2025-02-18
# Parsing articles from 2025-02-19 to 2025-02-24
# Parsing articles from 2025-02-25 to 2025-03-02
# Parsing articles from 2025-03-03 to 2025-03-08
# Parsing articles from 2025-03-09 to 2025-03-14
# Parsing articles from 2025-03-15 to 2025-03-20
# Finish
# 39477
# (39477, 16)
# Parsing articles from 2023-01-01 to 2023-01-06
# Parsing articles from 2023-01-07 to 2023-01-12
# Parsing articles from 2023-01-13 to 2023-01-18
# Parsing articles from 2023-01-19 to 2023-01-24
# Parsing articles from 2023-01-25 to 2023-01-30
# Parsing articles from 2023-01-31 to 2023-02-05
# Parsing articles from 2023-02-06 to 2023-02-11
# Parsing articles from 2023-02-12 to 2023-02-17
# Parsing articles from 2023-02-18 to 2023-02-23
# Parsing articles from 2023-02-24 to 2023-03-01
# Parsing articles from 2023-03-02 to 2023-03-07
# Parsing articles from 2023-03-08 to 2023-03-13
# Parsing articles from 2023-03-14 to 2023-03-19
# Parsing articles from 2023-03-20 to 2023-03-25
# Parsing articles from 2023-03-26 to 2023-03-31
# Parsing articles from 2023-04-01 to 2023-04-06
# Parsing articles from 2023-04-07 to 2023-04-12
# Parsing articles from 2023-04-13 to 2023-04-18
# Parsing articles from 2023-04-19 to 2023-04-24
# Parsing articles from 2023-04-25 to 2023-04-30
# Parsing articles from 2023-05-01 to 2023-05-06
# Parsing articles from 2023-05-07 to 2023-05-12
# Parsing articles from 2023-05-13 to 2023-05-18
# Parsing articles from 2023-05-19 to 2023-05-24
# Parsing articles from 2023-05-25 to 2023-05-30
# Parsing articles from 2023-05-31 to 2023-06-05
# Parsing articles from 2023-06-06 to 2023-06-11
# Parsing articles from 2023-06-12 to 2023-06-17
# Parsing articles from 2023-06-18 to 2023-06-23
# Parsing articles from 2023-06-24 to 2023-06-29
# Parsing articles from 2023-06-30 to 2023-07-05
# Parsing articles from 2023-07-06 to 2023-07-11
# Parsing articles from 2023-07-12 to 2023-07-17
# Parsing articles from 2023-07-18 to 2023-07-23
# Parsing articles from 2023-07-24 to 2023-07-29
# Parsing articles from 2023-07-30 to 2023-08-04
# Parsing articles from 2023-08-05 to 2023-08-10
# Parsing articles from 2023-08-11 to 2023-08-16
# Parsing articles from 2023-08-17 to 2023-08-22
# Parsing articles from 2023-08-23 to 2023-08-28
# Parsing articles from 2023-08-29 to 2023-09-03
# Parsing articles from 2023-09-04 to 2023-09-09
# Parsing articles from 2023-09-10 to 2023-09-15
# Parsing articles from 2023-09-16 to 2023-09-21
# Parsing articles from 2023-09-22 to 2023-09-27
# Parsing articles from 2023-09-28 to 2023-10-03
# Parsing articles from 2023-10-04 to 2023-10-09
# Parsing articles from 2023-10-10 to 2023-10-15
# Parsing articles from 2023-10-16 to 2023-10-21
# Parsing articles from 2023-10-22 to 2023-10-27
# Parsing articles from 2023-10-28 to 2023-11-02
# Parsing articles from 2023-11-03 to 2023-11-08
# Parsing articles from 2023-11-09 to 2023-11-14
# Parsing articles from 2023-11-15 to 2023-11-20
# Parsing articles from 2023-11-21 to 2023-11-26
# Parsing articles from 2023-11-27 to 2023-12-02
# Parsing articles from 2023-12-03 to 2023-12-08
# Parsing articles from 2023-12-09 to 2023-12-14
# Parsing articles from 2023-12-15 to 2023-12-20
# Parsing articles from 2023-12-21 to 2023-12-26
# Parsing articles from 2023-12-27 to 2024-01-01
# Parsing articles from 2024-01-02 to 2024-01-07
# Parsing articles from 2024-01-08 to 2024-01-13
# Parsing articles from 2024-01-14 to 2024-01-19
# Parsing articles from 2024-01-20 to 2024-01-25
# Parsing articles from 2024-01-26 to 2024-01-31
# Parsing articles from 2024-02-01 to 2024-02-06
# Parsing articles from 2024-02-07 to 2024-02-12
# Parsing articles from 2024-02-13 to 2024-02-18
# Parsing articles from 2024-02-19 to 2024-02-24
# Parsing articles from 2024-02-25 to 2024-03-01
# Parsing articles from 2024-03-02 to 2024-03-07
# Parsing articles from 2024-03-08 to 2024-03-13
# Parsing articles from 2024-03-14 to 2024-03-19
# Parsing articles from 2024-03-20 to 2024-03-25
# Parsing articles from 2024-03-26 to 2024-03-31
# Parsing articles from 2024-04-01 to 2024-04-06
# Parsing articles from 2024-04-07 to 2024-04-12
# Parsing articles from 2024-04-13 to 2024-04-18
# Parsing articles from 2024-04-19 to 2024-04-24
# Parsing articles from 2024-04-25 to 2024-04-30
# Parsing articles from 2024-05-01 to 2024-05-06
# Parsing articles from 2024-05-07 to 2024-05-12
# Parsing articles from 2024-05-13 to 2024-05-18
# Parsing articles from 2024-05-19 to 2024-05-24
# Parsing articles from 2024-05-25 to 2024-05-30
# Parsing articles from 2024-05-31 to 2024-06-05
# Parsing articles from 2024-06-06 to 2024-06-11
# Parsing articles from 2024-06-12 to 2024-06-17
# Parsing articles from 2024-06-18 to 2024-06-23
# Parsing articles from 2024-06-24 to 2024-06-29
# Parsing articles from 2024-06-30 to 2024-07-05
# Parsing articles from 2024-07-06 to 2024-07-11
# Parsing articles from 2024-07-12 to 2024-07-17
# Parsing articles from 2024-07-18 to 2024-07-23
# Parsing articles from 2024-07-24 to 2024-07-29
# Parsing articles from 2024-07-30 to 2024-08-04
# Parsing articles from 2024-08-05 to 2024-08-10
# Parsing articles from 2024-08-11 to 2024-08-16
# Parsing articles from 2024-08-17 to 2024-08-22
# Parsing articles from 2024-08-23 to 2024-08-28
# Parsing articles from 2024-08-29 to 2024-09-03
# Parsing articles from 2024-09-04 to 2024-09-09
# Parsing articles from 2024-09-10 to 2024-09-15
# Parsing articles from 2024-09-16 to 2024-09-21
# Parsing articles from 2024-09-22 to 2024-09-27
# Parsing articles from 2024-09-28 to 2024-10-03
# Parsing articles from 2024-10-04 to 2024-10-09
# Parsing articles from 2024-10-10 to 2024-10-15
# Parsing articles from 2024-10-16 to 2024-10-21
# Parsing articles from 2024-10-22 to 2024-10-27
# Parsing articles from 2024-10-28 to 2024-11-02
# Parsing articles from 2024-11-03 to 2024-11-08
# Parsing articles from 2024-11-09 to 2024-11-14
# Parsing articles from 2024-11-15 to 2024-11-20
# Parsing articles from 2024-11-21 to 2024-11-26
# Parsing articles from 2024-11-27 to 2024-12-02
# Parsing articles from 2024-12-03 to 2024-12-08
# Parsing articles from 2024-12-09 to 2024-12-14
# Parsing articles from 2024-12-15 to 2024-12-20
# Parsing articles from 2024-12-21 to 2024-12-26
# Parsing articles from 2024-12-27 to 2025-01-01
# Parsing articles from 2025-01-02 to 2025-01-07
# Parsing articles from 2025-01-08 to 2025-01-13
# Parsing articles from 2025-01-14 to 2025-01-19
# Parsing articles from 2025-01-20 to 2025-01-25
# Parsing articles from 2025-01-26 to 2025-01-31
# Parsing articles from 2025-02-01 to 2025-02-06
# Parsing articles from 2025-02-07 to 2025-02-12
# Parsing articles from 2025-02-13 to 2025-02-18
# Parsing articles from 2025-02-19 to 2025-02-24
# Parsing articles from 2025-02-25 to 2025-03-02
# Parsing articles from 2025-03-03 to 2025-03-08
# Parsing articles from 2025-03-09 to 2025-03-14
# Parsing articles from 2025-03-15 to 2025-03-20
# Finish
# 34536
# (34536, 16)
# Parsing articles from 2023-01-01 to 2023-01-06
# Parsing articles from 2023-01-07 to 2023-01-12
# Parsing articles from 2023-01-13 to 2023-01-18
# Parsing articles from 2023-01-19 to 2023-01-24
# Parsing articles from 2023-01-25 to 2023-01-30
# Parsing articles from 2023-01-31 to 2023-02-05
# Parsing articles from 2023-02-06 to 2023-02-11
# Parsing articles from 2023-02-12 to 2023-02-17
# Parsing articles from 2023-02-18 to 2023-02-23
# Parsing articles from 2023-02-24 to 2023-03-01
# Parsing articles from 2023-03-02 to 2023-03-07
# Parsing articles from 2023-03-08 to 2023-03-13
# Parsing articles from 2023-03-14 to 2023-03-19
# Parsing articles from 2023-03-20 to 2023-03-25
# Parsing articles from 2023-03-26 to 2023-03-31
# Parsing articles from 2023-04-01 to 2023-04-06
# Parsing articles from 2023-04-07 to 2023-04-12
# Parsing articles from 2023-04-13 to 2023-04-18
# Parsing articles from 2023-04-19 to 2023-04-24
# Parsing articles from 2023-04-25 to 2023-04-30
# Parsing articles from 2023-05-01 to 2023-05-06
# Parsing articles from 2023-05-07 to 2023-05-12
# Parsing articles from 2023-05-13 to 2023-05-18
# Parsing articles from 2023-05-19 to 2023-05-24
# Parsing articles from 2023-05-25 to 2023-05-30
# Parsing articles from 2023-05-31 to 2023-06-05
# Parsing articles from 2023-06-06 to 2023-06-11
# Parsing articles from 2023-06-12 to 2023-06-17
# Parsing articles from 2023-06-18 to 2023-06-23
# Parsing articles from 2023-06-24 to 2023-06-29
# Parsing articles from 2023-06-30 to 2023-07-05
# Parsing articles from 2023-07-06 to 2023-07-11
# Parsing articles from 2023-07-12 to 2023-07-17
# Parsing articles from 2023-07-18 to 2023-07-23
# Parsing articles from 2023-07-24 to 2023-07-29
# Parsing articles from 2023-07-30 to 2023-08-04
# Parsing articles from 2023-08-05 to 2023-08-10
# Parsing articles from 2023-08-11 to 2023-08-16
# Parsing articles from 2023-08-17 to 2023-08-22
# Parsing articles from 2023-08-23 to 2023-08-28
# Parsing articles from 2023-08-29 to 2023-09-03
# Parsing articles from 2023-09-04 to 2023-09-09
# Parsing articles from 2023-09-10 to 2023-09-15
# Parsing articles from 2023-09-16 to 2023-09-21
# Parsing articles from 2023-09-22 to 2023-09-27
# Parsing articles from 2023-09-28 to 2023-10-03
# Parsing articles from 2023-10-04 to 2023-10-09
# Parsing articles from 2023-10-10 to 2023-10-15
# Parsing articles from 2023-10-16 to 2023-10-21
# Parsing articles from 2023-10-22 to 2023-10-27
# Parsing articles from 2023-10-28 to 2023-11-02
# Parsing articles from 2023-11-03 to 2023-11-08
# Parsing articles from 2023-11-09 to 2023-11-14
# Parsing articles from 2023-11-15 to 2023-11-20
# Parsing articles from 2023-11-21 to 2023-11-26
# Parsing articles from 2023-11-27 to 2023-12-02
# Parsing articles from 2023-12-03 to 2023-12-08
# Parsing articles from 2023-12-09 to 2023-12-14
# Parsing articles from 2023-12-15 to 2023-12-20
# Parsing articles from 2023-12-21 to 2023-12-26
# Parsing articles from 2023-12-27 to 2024-01-01
# Parsing articles from 2024-01-02 to 2024-01-07
# Parsing articles from 2024-01-08 to 2024-01-13
# Parsing articles from 2024-01-14 to 2024-01-19
# Parsing articles from 2024-01-20 to 2024-01-25
# Parsing articles from 2024-01-26 to 2024-01-31
# Parsing articles from 2024-02-01 to 2024-02-06
# Parsing articles from 2024-02-07 to 2024-02-12
# Parsing articles from 2024-02-13 to 2024-02-18
# Parsing articles from 2024-02-19 to 2024-02-24
# Parsing articles from 2024-02-25 to 2024-03-01
# Parsing articles from 2024-03-02 to 2024-03-07
# Parsing articles from 2024-03-08 to 2024-03-13
# Parsing articles from 2024-03-14 to 2024-03-19
# Parsing articles from 2024-03-20 to 2024-03-25
# Parsing articles from 2024-03-26 to 2024-03-31
# Parsing articles from 2024-04-01 to 2024-04-06
# Parsing articles from 2024-04-07 to 2024-04-12
# Parsing articles from 2024-04-13 to 2024-04-18
# Parsing articles from 2024-04-19 to 2024-04-24
# Parsing articles from 2024-04-25 to 2024-04-30
# Parsing articles from 2024-05-01 to 2024-05-06
# Parsing articles from 2024-05-07 to 2024-05-12
# Parsing articles from 2024-05-13 to 2024-05-18
# Parsing articles from 2024-05-19 to 2024-05-24
# Parsing articles from 2024-05-25 to 2024-05-30
# Parsing articles from 2024-05-31 to 2024-06-05
# Parsing articles from 2024-06-06 to 2024-06-11
# Parsing articles from 2024-06-12 to 2024-06-17
# Parsing articles from 2024-06-18 to 2024-06-23
# Parsing articles from 2024-06-24 to 2024-06-29
# Parsing articles from 2024-06-30 to 2024-07-05
# Parsing articles from 2024-07-06 to 2024-07-11
# Parsing articles from 2024-07-12 to 2024-07-17
# Parsing articles from 2024-07-18 to 2024-07-23
# Parsing articles from 2024-07-24 to 2024-07-29
# Parsing articles from 2024-07-30 to 2024-08-04
# Parsing articles from 2024-08-05 to 2024-08-10
# Parsing articles from 2024-08-11 to 2024-08-16
# Parsing articles from 2024-08-17 to 2024-08-22
# Parsing articles from 2024-08-23 to 2024-08-28
# Parsing articles from 2024-08-29 to 2024-09-03
# Parsing articles from 2024-09-04 to 2024-09-09
# Parsing articles from 2024-09-10 to 2024-09-15
# Parsing articles from 2024-09-16 to 2024-09-21
# Parsing articles from 2024-09-22 to 2024-09-27
# Parsing articles from 2024-09-28 to 2024-10-03
# Parsing articles from 2024-10-04 to 2024-10-09
# Parsing articles from 2024-10-10 to 2024-10-15
# Parsing articles from 2024-10-16 to 2024-10-21
# Parsing articles from 2024-10-22 to 2024-10-27
# Parsing articles from 2024-10-28 to 2024-11-02
# Parsing articles from 2024-11-03 to 2024-11-08
# Parsing articles from 2024-11-09 to 2024-11-14
# Parsing articles from 2024-11-15 to 2024-11-20
# Parsing articles from 2024-11-21 to 2024-11-26
# Parsing articles from 2024-11-27 to 2024-12-02
# Parsing articles from 2024-12-03 to 2024-12-08
# Parsing articles from 2024-12-09 to 2024-12-14
# Parsing articles from 2024-12-15 to 2024-12-20
# Parsing articles from 2024-12-21 to 2024-12-26
# Parsing articles from 2024-12-27 to 2025-01-01
# Parsing articles from 2025-01-02 to 2025-01-07
# Parsing articles from 2025-01-08 to 2025-01-13
# Parsing articles from 2025-01-14 to 2025-01-19
# Parsing articles from 2025-01-20 to 2025-01-25
# Parsing articles from 2025-01-26 to 2025-01-31
# Parsing articles from 2025-02-01 to 2025-02-06
# Parsing articles from 2025-02-07 to 2025-02-12
# Parsing articles from 2025-02-13 to 2025-02-18
# Parsing articles from 2025-02-19 to 2025-02-24
# Parsing articles from 2025-02-25 to 2025-03-02
# Parsing articles from 2025-03-03 to 2025-03-08
# Parsing articles from 2025-03-09 to 2025-03-14
# Parsing articles from 2025-03-15 to 2025-03-20
# Finish
# 17186
# (17186, 16)
# Parsing articles from 2023-01-01 to 2023-01-06
# Parsing articles from 2023-01-07 to 2023-01-12
# Parsing articles from 2023-01-13 to 2023-01-18
# Parsing articles from 2023-01-19 to 2023-01-24
# Parsing articles from 2023-01-25 to 2023-01-30
# Parsing articles from 2023-01-31 to 2023-02-05
# Parsing articles from 2023-02-06 to 2023-02-11
# Parsing articles from 2023-02-12 to 2023-02-17
# Parsing articles from 2023-02-18 to 2023-02-23
# Parsing articles from 2023-02-24 to 2023-03-01
# Parsing articles from 2023-03-02 to 2023-03-07
# Parsing articles from 2023-03-08 to 2023-03-13
# Parsing articles from 2023-03-14 to 2023-03-19
# Parsing articles from 2023-03-20 to 2023-03-25
# Parsing articles from 2023-03-26 to 2023-03-31
# Parsing articles from 2023-04-01 to 2023-04-06
# Parsing articles from 2023-04-07 to 2023-04-12
# Parsing articles from 2023-04-13 to 2023-04-18
# Parsing articles from 2023-04-19 to 2023-04-24
# Parsing articles from 2023-04-25 to 2023-04-30
# Parsing articles from 2023-05-01 to 2023-05-06
# Parsing articles from 2023-05-07 to 2023-05-12
# Parsing articles from 2023-05-13 to 2023-05-18
# Parsing articles from 2023-05-19 to 2023-05-24
# Parsing articles from 2023-05-25 to 2023-05-30
# Parsing articles from 2023-05-31 to 2023-06-05
# Parsing articles from 2023-06-06 to 2023-06-11
# Parsing articles from 2023-06-12 to 2023-06-17
# Parsing articles from 2023-06-18 to 2023-06-23
# Parsing articles from 2023-06-24 to 2023-06-29
# Parsing articles from 2023-06-30 to 2023-07-05
# Parsing articles from 2023-07-06 to 2023-07-11
# Parsing articles from 2023-07-12 to 2023-07-17
# Parsing articles from 2023-07-18 to 2023-07-23
# Parsing articles from 2023-07-24 to 2023-07-29
# Parsing articles from 2023-07-30 to 2023-08-04
# Parsing articles from 2023-08-05 to 2023-08-10
# Parsing articles from 2023-08-11 to 2023-08-16
# Parsing articles from 2023-08-17 to 2023-08-22
# Parsing articles from 2023-08-23 to 2023-08-28
# Parsing articles from 2023-08-29 to 2023-09-03
# Parsing articles from 2023-09-04 to 2023-09-09
# Parsing articles from 2023-09-10 to 2023-09-15
# Parsing articles from 2023-09-16 to 2023-09-21
# Parsing articles from 2023-09-22 to 2023-09-27
# Parsing articles from 2023-09-28 to 2023-10-03
# Parsing articles from 2023-10-04 to 2023-10-09
# Parsing articles from 2023-10-10 to 2023-10-15
# Parsing articles from 2023-10-16 to 2023-10-21
# Parsing articles from 2023-10-22 to 2023-10-27
# Parsing articles from 2023-10-28 to 2023-11-02
# Parsing articles from 2023-11-03 to 2023-11-08
# Parsing articles from 2023-11-09 to 2023-11-14
# Parsing articles from 2023-11-15 to 2023-11-20
# Parsing articles from 2023-11-21 to 2023-11-26
# Parsing articles from 2023-11-27 to 2023-12-02
# Parsing articles from 2023-12-03 to 2023-12-08
# Parsing articles from 2023-12-09 to 2023-12-14
# Parsing articles from 2023-12-15 to 2023-12-20
# Parsing articles from 2023-12-21 to 2023-12-26
# Parsing articles from 2023-12-27 to 2024-01-01
# Parsing articles from 2024-01-02 to 2024-01-07
# Parsing articles from 2024-01-08 to 2024-01-13
# Parsing articles from 2024-01-14 to 2024-01-19
# Parsing articles from 2024-01-20 to 2024-01-25
# Parsing articles from 2024-01-26 to 2024-01-31
# Parsing articles from 2024-02-01 to 2024-02-06
# Parsing articles from 2024-02-07 to 2024-02-12
# Parsing articles from 2024-02-13 to 2024-02-18
# Parsing articles from 2024-02-19 to 2024-02-24
# Parsing articles from 2024-02-25 to 2024-03-01
# Parsing articles from 2024-03-02 to 2024-03-07
# Parsing articles from 2024-03-08 to 2024-03-13
# Parsing articles from 2024-03-14 to 2024-03-19
# Parsing articles from 2024-03-20 to 2024-03-25
# Parsing articles from 2024-03-26 to 2024-03-31
# Parsing articles from 2024-04-01 to 2024-04-06
# Parsing articles from 2024-04-07 to 2024-04-12
# Parsing articles from 2024-04-13 to 2024-04-18
# Parsing articles from 2024-04-19 to 2024-04-24
# Parsing articles from 2024-04-25 to 2024-04-30
# Parsing articles from 2024-05-01 to 2024-05-06
# Parsing articles from 2024-05-07 to 2024-05-12
# Parsing articles from 2024-05-13 to 2024-05-18
# Parsing articles from 2024-05-19 to 2024-05-24
# Parsing articles from 2024-05-25 to 2024-05-30
# Parsing articles from 2024-05-31 to 2024-06-05
# Parsing articles from 2024-06-06 to 2024-06-11
# Parsing articles from 2024-06-12 to 2024-06-17
# Parsing articles from 2024-06-18 to 2024-06-23
# Parsing articles from 2024-06-24 to 2024-06-29
# Parsing articles from 2024-06-30 to 2024-07-05
# Parsing articles from 2024-07-06 to 2024-07-11
# Parsing articles from 2024-07-12 to 2024-07-17
# Parsing articles from 2024-07-18 to 2024-07-23
# Parsing articles from 2024-07-24 to 2024-07-29
# Parsing articles from 2024-07-30 to 2024-08-04
# Parsing articles from 2024-08-05 to 2024-08-10
# Parsing articles from 2024-08-11 to 2024-08-16
# Parsing articles from 2024-08-17 to 2024-08-22
# Parsing articles from 2024-08-23 to 2024-08-28
# Parsing articles from 2024-08-29 to 2024-09-03
# Parsing articles from 2024-09-04 to 2024-09-09
# Parsing articles from 2024-09-10 to 2024-09-15
# Parsing articles from 2024-09-16 to 2024-09-21
# Parsing articles from 2024-09-22 to 2024-09-27
# Parsing articles from 2024-09-28 to 2024-10-03
# Parsing articles from 2024-10-04 to 2024-10-09
# Parsing articles from 2024-10-10 to 2024-10-15
# Parsing articles from 2024-10-16 to 2024-10-21
# Parsing articles from 2024-10-22 to 2024-10-27
# Parsing articles from 2024-10-28 to 2024-11-02
# Parsing articles from 2024-11-03 to 2024-11-08
# Parsing articles from 2024-11-09 to 2024-11-14
# Parsing articles from 2024-11-15 to 2024-11-20
# Parsing articles from 2024-11-21 to 2024-11-26
# Parsing articles from 2024-11-27 to 2024-12-02
# Parsing articles from 2024-12-03 to 2024-12-08
# Parsing articles from 2024-12-09 to 2024-12-14
# Parsing articles from 2024-12-15 to 2024-12-20
# Parsing articles from 2024-12-21 to 2024-12-26
# Parsing articles from 2024-12-27 to 2025-01-01
# Parsing articles from 2025-01-02 to 2025-01-07
# Parsing articles from 2025-01-08 to 2025-01-13
# Parsing articles from 2025-01-14 to 2025-01-19
# Parsing articles from 2025-01-20 to 2025-01-25
# Parsing articles from 2025-01-26 to 2025-01-31
# Parsing articles from 2025-02-01 to 2025-02-06
# Parsing articles from 2025-02-07 to 2025-02-12
# Parsing articles from 2025-02-13 to 2025-02-18
# Parsing articles from 2025-02-19 to 2025-02-24
# Parsing articles from 2025-02-25 to 2025-03-02
# Parsing articles from 2025-03-03 to 2025-03-08
# Parsing articles from 2025-03-09 to 2025-03-14
# Parsing articles from 2025-03-15 to 2025-03-20
# Finish
# 13093
# (13093, 16)
# Parsing articles from 2023-01-01 to 2023-01-06
# Parsing articles from 2023-01-07 to 2023-01-12
# Parsing articles from 2023-01-13 to 2023-01-18
# Parsing articles from 2023-01-19 to 2023-01-24
# Parsing articles from 2023-01-25 to 2023-01-30
# Parsing articles from 2023-01-31 to 2023-02-05
# Parsing articles from 2023-02-06 to 2023-02-11
# Parsing articles from 2023-02-12 to 2023-02-17
# Parsing articles from 2023-02-18 to 2023-02-23
# Parsing articles from 2023-02-24 to 2023-03-01
# Parsing articles from 2023-03-02 to 2023-03-07
# Parsing articles from 2023-03-08 to 2023-03-13
# Parsing articles from 2023-03-14 to 2023-03-19
# Parsing articles from 2023-03-20 to 2023-03-25
# Parsing articles from 2023-03-26 to 2023-03-31
# Parsing articles from 2023-04-01 to 2023-04-06
# Parsing articles from 2023-04-07 to 2023-04-12
# Parsing articles from 2023-04-13 to 2023-04-18
# Parsing articles from 2023-04-19 to 2023-04-24
# Parsing articles from 2023-04-25 to 2023-04-30
# Parsing articles from 2023-05-01 to 2023-05-06
# Parsing articles from 2023-05-07 to 2023-05-12
# Parsing articles from 2023-05-13 to 2023-05-18
# Parsing articles from 2023-05-19 to 2023-05-24
# Parsing articles from 2023-05-25 to 2023-05-30
# Parsing articles from 2023-05-31 to 2023-06-05
# Parsing articles from 2023-06-06 to 2023-06-11
# Parsing articles from 2023-06-12 to 2023-06-17
# Parsing articles from 2023-06-18 to 2023-06-23
# Parsing articles from 2023-06-24 to 2023-06-29
# Parsing articles from 2023-06-30 to 2023-07-05
# Parsing articles from 2023-07-06 to 2023-07-11
# Parsing articles from 2023-07-12 to 2023-07-17
# Parsing articles from 2023-07-18 to 2023-07-23
# Parsing articles from 2023-07-24 to 2023-07-29
# Parsing articles from 2023-07-30 to 2023-08-04
# Parsing articles from 2023-08-05 to 2023-08-10
# Parsing articles from 2023-08-11 to 2023-08-16
# Parsing articles from 2023-08-17 to 2023-08-22
# Parsing articles from 2023-08-23 to 2023-08-28
# Parsing articles from 2023-08-29 to 2023-09-03
# Parsing articles from 2023-09-04 to 2023-09-09
# Parsing articles from 2023-09-10 to 2023-09-15
# Parsing articles from 2023-09-16 to 2023-09-21
# Parsing articles from 2023-09-22 to 2023-09-27
# Parsing articles from 2023-09-28 to 2023-10-03
# Parsing articles from 2023-10-04 to 2023-10-09
# Parsing articles from 2023-10-10 to 2023-10-15
# Parsing articles from 2023-10-16 to 2023-10-21
# Parsing articles from 2023-10-22 to 2023-10-27
# Parsing articles from 2023-10-28 to 2023-11-02
# Parsing articles from 2023-11-03 to 2023-11-08
# Parsing articles from 2023-11-09 to 2023-11-14
# Parsing articles from 2023-11-15 to 2023-11-20
# Parsing articles from 2023-11-21 to 2023-11-26
# Parsing articles from 2023-11-27 to 2023-12-02
# Parsing articles from 2023-12-03 to 2023-12-08
# Parsing articles from 2023-12-09 to 2023-12-14
# Parsing articles from 2023-12-15 to 2023-12-20
# Parsing articles from 2023-12-21 to 2023-12-26
# Parsing articles from 2023-12-27 to 2024-01-01
# Parsing articles from 2024-01-02 to 2024-01-07
# Parsing articles from 2024-01-08 to 2024-01-13
# Parsing articles from 2024-01-14 to 2024-01-19
# Parsing articles from 2024-01-20 to 2024-01-25
# Parsing articles from 2024-01-26 to 2024-01-31
# Parsing articles from 2024-02-01 to 2024-02-06
# Parsing articles from 2024-02-07 to 2024-02-12
# Parsing articles from 2024-02-13 to 2024-02-18
# Parsing articles from 2024-02-19 to 2024-02-24
# Parsing articles from 2024-02-25 to 2024-03-01
# Parsing articles from 2024-03-02 to 2024-03-07
# Parsing articles from 2024-03-08 to 2024-03-13
# Parsing articles from 2024-03-14 to 2024-03-19
# Parsing articles from 2024-03-20 to 2024-03-25
# Parsing articles from 2024-03-26 to 2024-03-31
# Parsing articles from 2024-04-01 to 2024-04-06
# Parsing articles from 2024-04-07 to 2024-04-12
# Parsing articles from 2024-04-13 to 2024-04-18
# Parsing articles from 2024-04-19 to 2024-04-24
# Parsing articles from 2024-04-25 to 2024-04-30
# Parsing articles from 2024-05-01 to 2024-05-06
# Parsing articles from 2024-05-07 to 2024-05-12
# Parsing articles from 2024-05-13 to 2024-05-18
# Parsing articles from 2024-05-19 to 2024-05-24
# Parsing articles from 2024-05-25 to 2024-05-30
# Parsing articles from 2024-05-31 to 2024-06-05
# Parsing articles from 2024-06-06 to 2024-06-11
# Parsing articles from 2024-06-12 to 2024-06-17
# Parsing articles from 2024-06-18 to 2024-06-23
# Parsing articles from 2024-06-24 to 2024-06-29
# Parsing articles from 2024-06-30 to 2024-07-05
# Parsing articles from 2024-07-06 to 2024-07-11
# Parsing articles from 2024-07-12 to 2024-07-17
# Parsing articles from 2024-07-18 to 2024-07-23
# Parsing articles from 2024-07-24 to 2024-07-29
# Parsing articles from 2024-07-30 to 2024-08-04
# Parsing articles from 2024-08-05 to 2024-08-10
# Parsing articles from 2024-08-11 to 2024-08-16
# Parsing articles from 2024-08-17 to 2024-08-22
# Parsing articles from 2024-08-23 to 2024-08-28
# Parsing articles from 2024-08-29 to 2024-09-03
# Parsing articles from 2024-09-04 to 2024-09-09
# Parsing articles from 2024-09-10 to 2024-09-15
# Parsing articles from 2024-09-16 to 2024-09-21
# Parsing articles from 2024-09-22 to 2024-09-27
# Parsing articles from 2024-09-28 to 2024-10-03
# Parsing articles from 2024-10-04 to 2024-10-09
# Parsing articles from 2024-10-10 to 2024-10-15
# Parsing articles from 2024-10-16 to 2024-10-21
# Parsing articles from 2024-10-22 to 2024-10-27
# Parsing articles from 2024-10-28 to 2024-11-02
# Parsing articles from 2024-11-03 to 2024-11-08
# Parsing articles from 2024-11-09 to 2024-11-14
# Parsing articles from 2024-11-15 to 2024-11-20
# Parsing articles from 2024-11-21 to 2024-11-26
# Parsing articles from 2024-11-27 to 2024-12-02
# Parsing articles from 2024-12-03 to 2024-12-08
# Parsing articles from 2024-12-09 to 2024-12-14
# Parsing articles from 2024-12-15 to 2024-12-20
# Parsing articles from 2024-12-21 to 2024-12-26
# Parsing articles from 2024-12-27 to 2025-01-01
# Parsing articles from 2025-01-02 to 2025-01-07
# Parsing articles from 2025-01-08 to 2025-01-13
# Parsing articles from 2025-01-14 to 2025-01-19
# Parsing articles from 2025-01-20 to 2025-01-25
# Parsing articles from 2025-01-26 to 2025-01-31
# Parsing articles from 2025-02-01 to 2025-02-06
# Parsing articles from 2025-02-07 to 2025-02-12
# Parsing articles from 2025-02-13 to 2025-02-18
# Parsing articles from 2025-02-19 to 2025-02-24
# Parsing articles from 2025-02-25 to 2025-03-02
# Parsing articles from 2025-03-03 to 2025-03-08
# Parsing articles from 2025-03-09 to 2025-03-14
# Parsing articles from 2025-03-15 to 2025-03-20
# Finish
# 16298
# (16298, 16)
# Parsing articles from 2023-01-01 to 2023-01-06
# Parsing articles from 2023-01-07 to 2023-01-12
# Parsing articles from 2023-01-13 to 2023-01-18
# Parsing articles from 2023-01-19 to 2023-01-24
# Parsing articles from 2023-01-25 to 2023-01-30
# Parsing articles from 2023-01-31 to 2023-02-05
# Parsing articles from 2023-02-06 to 2023-02-11
# Parsing articles from 2023-02-12 to 2023-02-17
# Parsing articles from 2023-02-18 to 2023-02-23
# Parsing articles from 2023-02-24 to 2023-03-01
# Parsing articles from 2023-03-02 to 2023-03-07
# Parsing articles from 2023-03-08 to 2023-03-13
# Parsing articles from 2023-03-14 to 2023-03-19
# Parsing articles from 2023-03-20 to 2023-03-25
# Parsing articles from 2023-03-26 to 2023-03-31
# Parsing articles from 2023-04-01 to 2023-04-06
# Parsing articles from 2023-04-07 to 2023-04-12
# Parsing articles from 2023-04-13 to 2023-04-18
# Parsing articles from 2023-04-19 to 2023-04-24
# Parsing articles from 2023-04-25 to 2023-04-30
# Parsing articles from 2023-05-01 to 2023-05-06
# Parsing articles from 2023-05-07 to 2023-05-12
# Parsing articles from 2023-05-13 to 2023-05-18
# Parsing articles from 2023-05-19 to 2023-05-24
# Parsing articles from 2023-05-25 to 2023-05-30
# Parsing articles from 2023-05-31 to 2023-06-05
# Parsing articles from 2023-06-06 to 2023-06-11
# Parsing articles from 2023-06-12 to 2023-06-17
# Parsing articles from 2023-06-18 to 2023-06-23
# Parsing articles from 2023-06-24 to 2023-06-29
# Parsing articles from 2023-06-30 to 2023-07-05
# Parsing articles from 2023-07-06 to 2023-07-11
# Parsing articles from 2023-07-12 to 2023-07-17
# Parsing articles from 2023-07-18 to 2023-07-23
# Parsing articles from 2023-07-24 to 2023-07-29
# Parsing articles from 2023-07-30 to 2023-08-04
# Parsing articles from 2023-08-05 to 2023-08-10
# Parsing articles from 2023-08-11 to 2023-08-16
# Parsing articles from 2023-08-17 to 2023-08-22
# Parsing articles from 2023-08-23 to 2023-08-28
# Parsing articles from 2023-08-29 to 2023-09-03
# Parsing articles from 2023-09-04 to 2023-09-09
# Parsing articles from 2023-09-10 to 2023-09-15
# Parsing articles from 2023-09-16 to 2023-09-21
# Parsing articles from 2023-09-22 to 2023-09-27
# Parsing articles from 2023-09-28 to 2023-10-03
# Parsing articles from 2023-10-04 to 2023-10-09
# Parsing articles from 2023-10-10 to 2023-10-15
# Parsing articles from 2023-10-16 to 2023-10-21
# Parsing articles from 2023-10-22 to 2023-10-27
# Parsing articles from 2023-10-28 to 2023-11-02
# Parsing articles from 2023-11-03 to 2023-11-08
# Parsing articles from 2023-11-09 to 2023-11-14
# Parsing articles from 2023-11-15 to 2023-11-20
# Parsing articles from 2023-11-21 to 2023-11-26
# Parsing articles from 2023-11-27 to 2023-12-02
# Parsing articles from 2023-12-03 to 2023-12-08
# Parsing articles from 2023-12-09 to 2023-12-14
# Parsing articles from 2023-12-15 to 2023-12-20
# Parsing articles from 2023-12-21 to 2023-12-26
# Parsing articles from 2023-12-27 to 2024-01-01
# Parsing articles from 2024-01-02 to 2024-01-07
# Parsing articles from 2024-01-08 to 2024-01-13
# Parsing articles from 2024-01-14 to 2024-01-19
# Parsing articles from 2024-01-20 to 2024-01-25
# Parsing articles from 2024-01-26 to 2024-01-31
# Parsing articles from 2024-02-01 to 2024-02-06
# Parsing articles from 2024-02-07 to 2024-02-12
# Parsing articles from 2024-02-13 to 2024-02-18
# Parsing articles from 2024-02-19 to 2024-02-24
# Parsing articles from 2024-02-25 to 2024-03-01
# Parsing articles from 2024-03-02 to 2024-03-07
# Parsing articles from 2024-03-08 to 2024-03-13
# Parsing articles from 2024-03-14 to 2024-03-19
# Parsing articles from 2024-03-20 to 2024-03-25
# Parsing articles from 2024-03-26 to 2024-03-31
# Parsing articles from 2024-04-01 to 2024-04-06
# Parsing articles from 2024-04-07 to 2024-04-12
# Parsing articles from 2024-04-13 to 2024-04-18
# Parsing articles from 2024-04-19 to 2024-04-24
# Parsing articles from 2024-04-25 to 2024-04-30
# Parsing articles from 2024-05-01 to 2024-05-06
# Parsing articles from 2024-05-07 to 2024-05-12
# Parsing articles from 2024-05-13 to 2024-05-18
# Parsing articles from 2024-05-19 to 2024-05-24
# Parsing articles from 2024-05-25 to 2024-05-30
# Parsing articles from 2024-05-31 to 2024-06-05
# Parsing articles from 2024-06-06 to 2024-06-11
# Parsing articles from 2024-06-12 to 2024-06-17
# Parsing articles from 2024-06-18 to 2024-06-23
# Parsing articles from 2024-06-24 to 2024-06-29
# Parsing articles from 2024-06-30 to 2024-07-05
# Parsing articles from 2024-07-06 to 2024-07-11
# Parsing articles from 2024-07-12 to 2024-07-17
# Parsing articles from 2024-07-18 to 2024-07-23
# Parsing articles from 2024-07-24 to 2024-07-29
# Parsing articles from 2024-07-30 to 2024-08-04
# Parsing articles from 2024-08-05 to 2024-08-10
# Parsing articles from 2024-08-11 to 2024-08-16
# Parsing articles from 2024-08-17 to 2024-08-22
# Parsing articles from 2024-08-23 to 2024-08-28
# Parsing articles from 2024-08-29 to 2024-09-03
# Parsing articles from 2024-09-04 to 2024-09-09
# Parsing articles from 2024-09-10 to 2024-09-15
# Parsing articles from 2024-09-16 to 2024-09-21
# Parsing articles from 2024-09-22 to 2024-09-27
# Parsing articles from 2024-09-28 to 2024-10-03
# Parsing articles from 2024-10-04 to 2024-10-09
# Parsing articles from 2024-10-10 to 2024-10-15
# Parsing articles from 2024-10-16 to 2024-10-21
# Parsing articles from 2024-10-22 to 2024-10-27
# Parsing articles from 2024-10-28 to 2024-11-02
# Parsing articles from 2024-11-03 to 2024-11-08
# Parsing articles from 2024-11-09 to 2024-11-14
# Parsing articles from 2024-11-15 to 2024-11-20
# Parsing articles from 2024-11-21 to 2024-11-26
# Parsing articles from 2024-11-27 to 2024-12-02
# Parsing articles from 2024-12-03 to 2024-12-08
# Parsing articles from 2024-12-09 to 2024-12-14
# Parsing articles from 2024-12-15 to 2024-12-20
# Parsing articles from 2024-12-21 to 2024-12-26
# Parsing articles from 2024-12-27 to 2025-01-01
# Parsing articles from 2025-01-02 to 2025-01-07
# Parsing articles from 2025-01-08 to 2025-01-13
# Parsing articles from 2025-01-14 to 2025-01-19
# Parsing articles from 2025-01-20 to 2025-01-25
# Parsing articles from 2025-01-26 to 2025-01-31
# Parsing articles from 2025-02-01 to 2025-02-06
# Parsing articles from 2025-02-07 to 2025-02-12
# Parsing articles from 2025-02-13 to 2025-02-18
# Parsing articles from 2025-02-19 to 2025-02-24
# Parsing articles from 2025-02-25 to 2025-03-02
# Parsing articles from 2025-03-03 to 2025-03-08
# Parsing articles from 2025-03-09 to 2025-03-14
# Parsing articles from 2025-03-15 to 2025-03-20
# Finish
# 22334
# (22334, 16)

# %%
df.shape
# Out:
# (264387, 16)

# %% [markdown]
# Напарсили очень много данных.

# %%
df.head(3)
# Out:
#      docid                                          url  \
# 0  1365128    https://lenta.ru/news/2023/01/07/texnika/
# 1  1365127  https://lenta.ru/news/2023/01/07/patriarh_/
# 2  1365126     https://lenta.ru/news/2023/01/07/tiktok/
#
#                                                title    modified  lastmodtime  \
# 0  Пентагон рассказал о помощи украинским военным...  1673048915   1673048915
# 1     Патриарх Кирилл назвал условие мира на Украине  1673048590   1673048590
# 2  Американским чиновникам задумали запретить исп...  1673048183   1673048183
#
#    type  domain  status  part  bloc tags  \
# 0     1       1       0     1     2  [1]
# 1     1       1       0     0     1  [1]
# 2     1       1       0     0     2  [1]
#
#                                            image_url     pubdate  \
# 0  https://icdn.lenta.ru/images/2023/01/07/02/202...  1673048915
# 1  https://icdn.lenta.ru/images/2023/01/07/02/202...  1673048590
# 2  https://icdn.lenta.ru/images/2023/01/07/02/202...  1673048183
#
#                                                 text  \
# 0  Фото: 2nd Lt. Emily Park/ Globallookpress.com ...
# 1  Патриарх Московский и всея Руси Кирилл Фото: K...
# 2  Фото: Dado Ruvic / Reuters Марина Совина Губер...
#
#                                             rightcol  \
# 0  Пентагон рассказал о помощи украинским военным...
# 1     Патриарх Кирилл назвал условие мира на Украине
# 2  Американским чиновникам задумали запретить исп...
#
#                                              snippet
# 0  Фото: 2nd Lt. Emily Park/ Globallookpress.com ...
# 1  Патриарх Московский и всея Руси Кирилл ... и в...
# 2  Фото: Dado Ruvic / Reuters Марина Совина ... B...

# %%
df_processed = df.drop(['tags', 'url', 'image_url'], axis=1)

# %%
df_processed.shape
# Out:
# (264387, 13)

# %%
df_processed.duplicated().sum()
# Out:
# np.int64(28730)

# %%
df_dropped_dublicates = df_processed.drop_duplicates()

# %%
df_dropped_dublicates.shape
# Out:
# (235657, 13)

# %%
df_dropped_dublicates['bloc'].value_counts(normalize=True)
# Out:
# bloc
# 2      0.171860
# 1      0.171703
# 3      0.167519
# 4      0.146552
# 8      0.094773
# 5      0.072928
# 7      0.069160
# 6      0.055560
# 0      0.012624
# 37     0.011636
# 47     0.005589
# 48     0.005016
# 9      0.004591
# 87     0.004091
# 12     0.003768
# 86     0.002143
# 49     0.000458
# 120    0.000021
# 40     0.000008
# Name: proportion, dtype: float64

# %%
df_normalized_topics = df_dropped_dublicates[df_dropped_dublicates.bloc.isin([1, 37, 3, 4, 5, 8, 48, 87])]
TagsMap = {1 : 0, 3 : 3, 4 : 1, 5 : 8, 8 : 4, 37 : 2, 48 : 7, 87 : 5}
df_normalized_topics['topic'] = df_normalized_topics['bloc'].map(TagsMap)
# Out:
# <ipython-input-15-c7b36aabef7a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_normalized_topics['topic'] = df_normalized_topics['bloc'].map(TagsMap)

# %%
df_normalized_topics['topic'].value_counts(normalize=True) # можно сверить с распределением меток классов в соревновании
# Out:
# topic
# 0    0.254670
# 3    0.248464
# 1    0.217366
# 4    0.140568
# 8    0.108167
# 2    0.017258
# 7    0.007439
# 5    0.006067
# Name: proportion, dtype: float64

# %%
new_df = df_normalized_topics[~df_normalized_topics.text.isna()]
print(len(df_normalized_topics), len(new_df))
# Out:
# 158884 154303

# %%
new_df['len'] = new_df['text'].apply(lambda x: len(x))
# Out:
# <ipython-input-18-94b6dcd94183>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['len'] = new_df['text'].apply(lambda x: len(x))

# %%
new_df['len'].describe()
# Out:
# count    154303.000000
# mean       1379.556671
# std        1581.247706
# min           0.000000
# 25%         871.000000
# 50%        1061.000000
# 75%        1387.000000
# max       52185.000000
# Name: len, dtype: float64

# %%
new_min_len = new_df[new_df['len'] > 500]
new_min_len.shape
# Out:
# (153456, 15)

# %%
new_min_len.to_csv("articles.csv", index=True)

# %% [markdown]
# На этом часть с парсером закончена.
